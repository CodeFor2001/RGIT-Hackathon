# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

#loading heart dataset 

heart = pd.read_csv("heart.csv")
print("dataset loaded")
# Out:
# dataset loaded

# %%
#to specify column names
column_names = ['age', 'sex', 'cp', 'trestbps','chol', 'fbs', 'restecg','thalach', 'exang', 'oldpeak','slope','ca','thal','target']
heart.columns = column_names
print(heart.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
print(heart.shape)
# Out:
# (303, 14)

# %%
heart["target"].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
sb.pairplot(heart, hue="target")
plt.show();

# %%
#histogram with respect to age

sb.FacetGrid(heart, hue="target", size = 6)\
  .map(sb.distplot, "age")\
  .add_legend();

# %%
sb.FacetGrid(heart, hue="target", size = 6)\
  .map(sb.distplot, "trestbps")\
  .add_legend();

# %%
sb.FacetGrid(heart, hue="target", size = 6)\
  .map(sb.distplot, "restecg")\
  .add_legend(); 
#if restecg=1 hugh chances of heart attack

# %%
sb.FacetGrid(heart, hue="target", size = 6)\
  .map(sb.distplot, "thalach")\
  .add_legend();

# %%
sb.FacetGrid(heart, hue="target", size = 6)\
  .map(sb.distplot, "exang")\
  .add_legend(); 
#exang = 0 target =1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-87f745f18cc0> in <module>
#       1 sb.FacetGrid(heart, hue="target", size = 6)\
# ----> 2   .map(sb.distplot, "exang")\
#       3   .add_legend();
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
# ...

# %%
sb.FacetGrid(heart, hue="target", size = 6)\
  .map(sb.distplot, "oldpeak")\
  .add_legend();

# %%
sb.FacetGrid(heart, hue="target", size = 6)\
  .map(sb.distplot, "slope")\
  .add_legend();

# %%
sb.FacetGrid(heart, hue="target", size = 6)\
  .map(sb.distplot, "ca")\
  .add_legend();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-b0a6cfe13a48> in <module>
#       1 sb.FacetGrid(heart, hue="target", size = 6)\
# ----> 2   .map(sb.distplot, "ca")\
#       3   .add_legend();
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
# ...

# %%
sb.FacetGrid(heart, hue="target", size = 6)\
  .map(sb.distplot, "thal")\
  .add_legend();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-1bc3af723df1> in <module>
#       1 sb.FacetGrid(heart, hue="target", size = 6)\
# ----> 2   .map(sb.distplot, "thal")\
#       3   .add_legend();
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     765
#     766             # Draw the plot
# --> 767             self._facet_plot(func, ax, plot_args, kwargs)
#     768
# ...

# %%
sb.boxplot(x="target", y="age", data= heart)
plt.show();

# %%
sb.boxplot(x="sex", y="target", data= heart)
plt.show();

# %%
sb.relplot(x="sex", y="target", data= heart)

# %%
plot = sb.heatmap(heart.corr(), linewidths=0 )
